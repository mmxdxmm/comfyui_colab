# %% [markdown]
# <a href="https://colab.research.google.com/github/mmxdxmm/comfyui_colab/blob/main/comfyui_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#连接到谷歌云盘
from google.colab import drive
drive.mount('/content/drive')

# %%
#安装comfyui安装程序
# !pip install comfy-cli

# %%
#安装comfyui
# !yes | comfy install --nvidia

# %% [markdown]
# 下载模型，先下载再运行，免得麻烦。该模型为示例工作流中的2d文生图模型，可跳过，其他模型在后面。

# %%
#下载工作流示例和模型
# !mkdir -p /root/comfy/ComfyUI/user/default/workflows
# !curl -L -o /root/comfy/ComfyUI/user/default/workflows/2d作画.json https://raw.githubusercontent.com/mmxdxmm/comfyui_colab/refs/heads/main/2d.json
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/checkpoints/noobaiXLNAIXL_vPred10Version.safetensors" "https://huggingface.co/misri/noobaiXLNAIXL_vPred10Version/resolve/main/noobaiXLNAIXL_vPred10Version.safetensors"

# %%
#下载并安装cloudflared内网穿透工具
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# %%
#后台运行内网穿透，并将输出写入日志output.log，请在该文件中查看面板地址
# !nohup cloudflared tunnel --url http://127.0.0.1:8188 --protocol http2 > output.log 2>&1 &

# %%
#连接comfyui输出文件夹至谷歌云盘
# !rm -rf /root/comfy/ComfyUI/output
# !mkdir -p /content/drive/MyDrive/ComfyUI/output
# !ln -s /content/drive/MyDrive/ComfyUI/output /root/comfy/ComfyUI/output

# %%
#运行UI（优先使用显存；异步；半精度，只缓存最近使用的一个模型）
# !python3 /root/comfy/ComfyUI/main.py --highvram --async-offload --fp16-unet --fp16-vae --cache-lru 1

# %% [markdown]
# flux图片扩写模型

# %%
#下载工作流示例和模型
# !mkdir -p /root/comfy/ComfyUI/user/default/workflows
# !curl -L -o /root/comfy/ComfyUI/user/default/workflows/图片扩写.json https://raw.githubusercontent.com/mmxdxmm/comfyui_colab/refs/heads/main/flux_fill_inpaint_example.json
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/text_encoders/clip_l.safetensors" "https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/clip_l.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/text_encoders/t5xxl_fp16.safetensors" "https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/t5xxl_fp16.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/vae/ae.safetensors" "https://huggingface.co/Comfy-Org/Lumina_Image_2.0_Repackaged/resolve/main/split_files/vae/ae.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/diffusion_models/flux1-fill-dev.safetensors" "https://huggingface.co/Comfy-Org/flux1-dev/resolve/main/split_files/diffusion_models/flux1-fill-dev.safetensors"

# %% [markdown]
# wan2.2 5b 文/图生视频模型

# %%
#下载工作流示例和模型
# !mkdir -p /root/comfy/ComfyUI/user/default/workflows
# !curl -L -o /root/comfy/ComfyUI/user/default/workflows/文生视频.json https://raw.githubusercontent.com/mmxdxmm/comfyui_colab/refs/heads/main/text_to_video_wan22_5B.json
# !curl -L -o /root/comfy/ComfyUI/user/default/workflows/图文生视频.json https://raw.githubusercontent.com/mmxdxmm/comfyui_colab/refs/heads/main/video_wan2_2_5B_ti2v.json
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/diffusion_models/wan2.2_ti2v_5B_fp16.safetensors" "https://huggingface.co/Comfy-Org/Wan_2.2_ComfyUI_Repackaged/resolve/main/split_files/diffusion_models/wan2.2_ti2v_5B_fp16.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors" "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/text_encoders/umt5_xxl_fp8_e4m3fn_scaled.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/vae/wan2.2_vae.safetensors" "https://huggingface.co/Comfy-Org/Wan_2.2_ComfyUI_Repackaged/resolve/main/split_files/vae/wan2.2_vae.safetensors"

# %% [markdown]
# flux1 dev 根据参考图更换场景

# %%
#下载工作流示例和模型
# !mkdir -p /root/comfy/ComfyUI/user/default/workflows
# !curl -L -o /root/comfy/ComfyUI/user/default/workflows/参考图像换风格.json https://raw.githubusercontent.com/mmxdxmm/comfyui_colab/refs/heads/main/flux1_dev_uso_reference_image_gen.json
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/checkpoints/flux1-dev-fp8.safetensors" "https://huggingface.co/Comfy-Org/flux1-dev/resolve/main/flux1-dev-fp8.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/clip_vision/sigclip_vision_patch14_384.safetensors" "https://huggingface.co/Comfy-Org/sigclip_vision_384/resolve/main/sigclip_vision_patch14_384.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/model_patches/uso-flux1-projector-v1.safetensors" "https://huggingface.co/Comfy-Org/USO_1.0_Repackaged/resolve/main/split_files/model_patches/uso-flux1-projector-v1.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/loras/uso-flux1-dit-lora-v1.safetensors" "https://huggingface.co/Comfy-Org/USO_1.0_Repackaged/resolve/main/split_files/loras/uso-flux1-dit-lora-v1.safetensors"

# %% [markdown]
# flux1-dev 低显存

# %%
#下载工作流示例和模型
# !mkdir -p /root/comfy/ComfyUI/user/default/workflows
# !curl -L -o /root/comfy/ComfyUI/user/default/workflows/低显存文生图.json https://raw.githubusercontent.com/mmxdxmm/comfyui_colab/refs/heads/main/flux_dev_checkpoint_example.json
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/diffusion_models/flux1-dev.safetensors" "https://huggingface.co/Comfy-Org/flux1-dev/resolve/main/flux1-dev.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/text_encoders/clip_l.safetensors" "https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/clip_l.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/text_encoders/t5xxl_fp16.safetensors" "https://huggingface.co/comfyanonymous/flux_text_encoders/resolve/main/t5xxl_fp16.safetensors"

# %% [markdown]
# image-z-image-tubo

# %%
#下载工作流示例和模型
# !mkdir -p /root/comfy/ComfyUI/user/default/workflows
# !curl -L -o /root/comfy/ComfyUI/user/default/workflows/zimage文生图.json https://raw.githubusercontent.com/mmxdxmm/comfyui_colab/refs/heads/main/image_z_image_turbo.json
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/text_encoders/qwen_3_4b.safetensors" "https://huggingface.co/Comfy-Org/z_image_turbo/resolve/main/split_files/text_encoders/qwen_3_4b.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/loras/pixel_art_style_z_image_turbo.safetensors" "https://huggingface.co/tarn59/pixel_art_style_lora_z_image_turbo/resolve/main/pixel_art_style_z_image_turbo.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/diffusion_models/z_image_turbo_bf16.safetensors" "https://huggingface.co/Comfy-Org/z_image_turbo/resolve/main/split_files/diffusion_models/z_image_turbo_bf16.safetensors"
# !wget --content-disposition -O "/root/comfy/ComfyUI/models/vae/ae.safetensors" "https://huggingface.co/Comfy-Org/z_image_turbo/resolve/main/split_files/vae/ae.safetensors"
